# %%
#Import the random module
import random

# %%
# outcome:   single integer
random.randint(-90,90)
# Out:
# -67

# %%
#outcome:  returns only a floating-point decimal number between 0 and 1.0
random.random()
# Out:
# 0.695000610782402

# %%
#mixing both to generate a floating-point decimal between –90 and 90. e can write an algorithm that will generate latitudes between –90 and 89
random_number = random.randint(-90, 89) + random.random()
random_number
# Out:
# -76.71025025475605

# %%
x = 1
latitudes = []
while x < 11:
    random_lat = random.randint(-90, 89) + random.random()
    latitudes.append(random_lat)
    x += 1

# %%
#test randrange() function
random.randrange(-90, 90, step=1)
# Out:
# 48

# %%
random.randrange(-90, 90, step=3)
# Out:
# -63

# %%
#Import NumPy module. There is no need to import the random module if we import the NumPy module, as it's redundant. 
import numpy as np

# %%
np.random.uniform(-90.000, 90.000)
# Out:
# 63.97680065946054

# %%
np.random.uniform(-90.000, 90.000, size=50)
# Out:
# array([-18.28209034, -85.67572637, -40.28125987, -78.17543757,
#          2.63269361, -51.36667328, -43.0113308 , -16.37373906,
#         85.11893714, -18.33874391, -77.49743227, -56.1229491 ,
#        -87.34155199,  64.6078603 ,  15.4137078 ,  19.80458114,
#         74.3044837 , -20.59375756, -58.09535339, -18.75332908,
#         62.34617587, -15.79118947, -86.40202767, -73.0323655 ,
#          2.00391152,  41.36352055, -18.06029841,  46.10632343,
#         26.85508293,  77.77587505,  80.04242657,  -2.48547648,
#         63.034422  ,  25.28409915, -18.55728475, -65.66376381,
#        -62.39946656, -48.19114233, -55.16482052, -13.09731088,
#          5.34127906,  10.12105165, -65.34122566, -46.28669634,
#        -12.13053194,  54.67541271,  -9.16242574,  25.52989421,
#        -59.12140599,  82.19582709])

# %%
# Import timeit
import timeit

# %%
# %timeit np.random.uniform(-90.000, 90.000, size=1500)
# Out:
# 13.2 µs ± 294 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 1500.
# %timeit latitudes(1500)
# Out:
# 1.39 ms ± 17 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
